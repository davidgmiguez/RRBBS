# %% [markdown]
# # Minimal network motifs: Positive Feedback Loop
#
# A positive feedback loop is a minimal network motif where the product of transcription activates directly or indirectly the expression of its own mRNA.  A classic example of positive feedback is the lac operon in E. coli. Positive feedbacks play an integral role in cellular differentiation, development, and cancer progression, and therefore, positive feedback in gene regulation can have significant physiological consequences. Random motions in molecular dynamics coupled with positive feedback can create population of phenotypically different cells from the same parent cell. Perharps, the most simple and direct system with a positive feedback is a protein `P` that activates the expression of its own `mRNA`. Based on the model of the Central Dogma, the set of interactions that we will take into account are:
#
# $$
# \begin{matrix}
# \Psi (K,P,n) &\overset{α_M}{\longrightarrow}& M & \tag{1} \\
# M &\overset{\gamma_M}{\longrightarrow}& 0 & \\
# M &\overset{\alpha_P}{\longrightarrow}& P  & \\
# P &\overset{\gamma_P}{\longrightarrow}& 0 &\\
# \end{matrix}
# $$
#
# where $\Psi (K,P,n)$ is the Hill Function for activators, using `P` as transcription factor, with a half maximal concentration `K` and cooperativity `n`:
#
# $$
# \begin{align*}
# \Psi (K,P,n) &=  \frac{[P]^n}{K^n+[P]^n} \tag{2}
# \end{align*}
# $$
#
# Based on this, and using Mass action laws, we can write the set of differential equations as:
#
# $$
# \begin{align*}
# \frac{\mathrm{d} [M]}{\mathrm{d} t} &=  \alpha_m \frac{[P]^n}{K^n+[P]^n}-\gamma_M[M] \tag{3}\\
# \frac{\mathrm{d} [P]}{\mathrm{d} t} &=  \alpha_P [M]-\gamma_P[P] \tag{4}
# \end{align*}
# $$
#
# To study the features of a network motif with a positive feedback loop, we will start by building the ODE problem for this positive regulation and compare its dynamical properties with a linear system, where the activation of transcriptions is performed by another protein `T`, such as
#
# $$
# \begin{align*}
# \frac{\mathrm{d} [M]}{\mathrm{d} t} &=  \alpha_m \frac{T^n}{K^n+[T]^n}-\gamma_M[M] \tag{5}\\
# \frac{\mathrm{d} [P]}{\mathrm{d} t} &=  \alpha_P [M]-\gamma_P[P] \tag{6}
# \end{align*}
# $$

# %%
using Plots; gr()
using DifferentialEquations
using ParameterizedFunctions

# %%
PositiveFeedback! = @ode_def ab begin
   dM = -γ_M*M+α_M*P^n/(K^n +P^n)
   dP =   α_P * M - γ_P * P
    end α_M γ_M T n α_P γ_P K
# Out:
# (::ab{var"#67#71",var"#68#72",var"#69#73",Nothing,Nothing,var"#70#74",Expr,Expr}) (generic function with 2 methods)

# %%
NoFeedback! = @ode_def ab begin
   dM = -γ_M*M+α_M*T^n/(K^n +T^n)
   dP =   α_P * M - γ_P * P
    end α_M γ_M T n α_P γ_P K
# Out:
# (::ab{var"#75#79",var"#76#80",var"#77#81",Nothing,Nothing,var"#78#82",Expr,Expr}) (generic function with 2 methods)

# %% [markdown]
# ## Positive feedback loops have slower responses compared to linear networks
# We start by comparing the simples case, of Hill coefficient `n=1`. we will set the value of transcription factor `T` as the steady state value of the protein `P`, in order to maintain the same input intensity of the transcription.  We can see that the steady state is reached later when proteins are inside a positive feedback loop.

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
n=1
K=1
k_m=1
D=1
T=3
α_M=k_m*D
γ_M=0.3
α_P=0.6
γ_P=0.5
p=[α_M,γ_M,T,n,α_P,γ_P,K];

prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
prob2 = ODEProblem(NoFeedback!,u₀,tspan,p)

sol1 = solve(prob1)
P1=plot(sol1,label=["mRNA","Protein"])
title!("Positive feedback")
xlabel!("Time [s]")
ylabel!("Concentration [M]")

sol2 = solve(prob2)
P2=plot(sol2,label=["mRNA","Protein"])
title!("Linear")
xlabel!("Time [s]")
ylabel!("Concentration [M]")

plot(P1,P2,layout=(1,2),legend=true)

# %% [markdown]
# ## Postitive feedback loops reduce the robustness against changes in a parameter
#
# We will change in a loop the degradation of the mRNA protein, and compare how much the output, in terms of protein levels, changes as the parameter changes.

# %%
function PlotPositiveFeedback(γ_M)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     sol1 = solve(prob1)
     x=("gamma_M = $(γ_M)")
     plot!(sol1,vars=(2),label=x,ylims = (0,15)) 
end
# Out:
# PlotPositiveFeedback (generic function with 1 method)

# %%
function PlotLinear(γ_M)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(NoFeedback!,u₀,tspan,p)
     sol1 = solve(prob1)
     x=("gamma_M = $(γ_M)")
     plot!(sol1,vars=(2),label=x,ylims = (0,15))  
end
# Out:
# PlotLinear (generic function with 1 method)

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
plot()
for i in [0.1,0.3, 0.5]
    plot(PlotPositiveFeedback(i),legend=true)
end
     xlabel!("Time [s]")
       ylabel!("Concentration of Protein [M]")
     title!("Positive feedback")

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
plot()
for i in [0.1,0.3, 0.5]
    PlotLinear(i)
end
 xlabel!("Time [s]")
     ylabel!("Concentration of Protein [M]")
 title!("Linear function")

# %% [markdown]
# Now we will perform the same study of robustness, but changing the parameter `K`

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
n=1
K=1
k_m=1
D=1
T=3
α_M=k_m*D
γ_M=0.3
α_P=0.6
γ_P=0.5
p=[α_M,γ_M,T,n,α_P,γ_P,K];

# %%
function PlotPositiveFeedback(K)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     x=("K = $(K)")
     sol1 = solve(prob1)
     plot!(sol1,vars=(2),label=x,ylims = (0,4))
end

function PlotLinear(K)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(NoFeedback!,u₀,tspan,p)
     sol1 = solve(prob1)
     x=("K = $(K)")
     plot!(sol1,vars=(2),label=x,ylims = (0,4))  
end
# Out:
# PlotLinear (generic function with 1 method)

# %%
u0 = [0.2,0.01]
γ_M=0.3
tspan = (0.0,50.0)
plot()
for i in [0.5,2,3]
    PlotPositiveFeedback(i)
end
     xlabel!("Time [s]")
      ylabel!("Concentration of Protein [M]")
     title!("Positive feedback")

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
plot()
for i in [0.5,2,3]
    PlotLinear(i)
end
 title!("Linear function")
  ylabel!("Concentration of Protein [M]")
     title!("Positive feedback")

# %% [markdown]
# In both cases analyzed, the change in the output is larger when we include a positive feeback loop in the network, compare to a simple linear network with the same parameter values.

# %% [markdown]
# ## Positive Feedbacks are very sensitive is systems with Cooperativity

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
n=1
K=1
k_m=1
D=1
T=3
α_M=k_m*D
γ_M=0.3
α_P=0.6
γ_P=0.5
p=[α_M,γ_M,T,n,α_P,γ_P,K];

# %%
function PlotPositiveFeedback(n)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     x=("n = $(n)")
     sol1 = solve(prob1)
     plot!(sol1,vars=(2),label=x,ylims = (0,4))
end

function PlotLinear(n)
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(NoFeedback!,u₀,tspan,p)
     sol1 = solve(prob1)
     x=("n = $(n)")
     plot!(sol1,vars=(2),label=x,ylims = (0,4))  
end
# Out:
# PlotLinear (generic function with 1 method)

# %%
K=0.5
plot()
for i in [1,5,7]
    PlotPositiveFeedback(i)
end
     xlabel!("Time [s]")
      ylabel!("Concentration of Protein [M]")
     title!("Positive feedback")

# %%
plot()
for i in [1,5,7]
    PlotLinear(i)
end
     xlabel!("Time [s]")
      ylabel!("Concentration of Protein [M]")
     title!("No feedback")

# %% [markdown]
# ## Positive Feedbacks can add a delay in signal activation
#
# Apart from slowing the dynamics, positive feedback can introduce a delay in the activation of teh production of protein. This delay occurs because there is a longer excursion in the phase space, because the positive feedback can gererate more basins of atraction (see next section), slowing the trantitions towards its steady state solution.

# %%
K=0.2
plot()
for i in [1,5,7]
    PlotPositiveFeedback(i)
end
     xlabel!("Time [s]")
      ylabel!("Concentration of Protein [M]")
     title!("Positive feedback")

# %%
plot()
for i in [1,5,7]
    PlotLinear(i)
end
     xlabel!("Time [s]")
      ylabel!("Concentration of Protein [M]")
     title!("No feedback")

# %% [markdown]
# ## Positive Feedbacks can amplify noisy
#
# we will test how well a system with a positive feedback behaves when one of the variabes has a stochastic component. As with the nonlinear negative feedbakc and the linear cascade,, we will define a function to add additive noise into all variables of a system of differential equations in the following general formulation
#
# $$
# du=f(u,p,t)dt+g(u,p,t)dW
# $$
#
# Solving `SDEs` is done in the same way as `ODEs` in Julia. In the case of additive noise, `g` is simply a matrix of values. The simplest case is diagonal noise, where g is a diagonal matrix, with components $\lambda_i$. This means that every function in the system gets a different random number of similar amplitude. We simply define both `f` and `g` as in-place functions. Thus `f(du,u,p,t)` gives the deterministic change, and `g(du,u,p,t)` gives the stochastic portion of the equation. This way, the amplitude of noise is defined as $\lambda_i$ *N(0,dt) where `N` is the normal distribution.
#
# The general formulation for `SDEs` in Julia is the following
#
# `prob = SDEProblem(f!,g!,u₀,tspan,p)`
#
# At this point, we will only add noise in the mRNA production, trying to mimic the inherent variability due to staochasticity in activation and deactivation of gene transcripton.

# %%
NoiseFunction! = @ode_def negFB begin
   dM = 0.04
   dP = 0.0
    end α_M γ_M T n α_P γ_P K
# Out:
# (::negFB{var"#115#119",var"#116#120",var"#117#121",Nothing,Nothing,var"#118#122",Expr,Expr}) (generic function with 2 methods)

# %%
u₀ = [0.2,0.01]
tspan = (0.0,50.0)
n=1
K=1
k_m=1
D=1
T=3
α_M=k_m*D
γ_M=0.3
α_P=0.6
γ_P=0.5
p=[α_M,γ_M,T,n,α_P,γ_P,K];

prob6 = SDEProblem(PositiveFeedback!,NoiseFunction!,u₀,tspan,p)
prob7 = MonteCarloProblem(prob6)
sol7 = solve(prob7,trajectories=10);
summ7 = EnsembleSummary(sol7,0:1:50)
plot(summ7,labels="Middle 95%")
summ8 = EnsembleSummary(sol7,0:1:50;quantiles=[0.35,0.65])
plot!(summ8,labels="Middle 50%",legend=true)
title!("Response to variability of positive feedback GRN")
xlabel!("Time [s]")
ylabel!("Concentration[M]")

# %%
prob8 = SDEProblem(NoFeedback!,NoiseFunction!,u₀,tspan,p)
#sol8 = solve(prob8)
prob9 = MonteCarloProblem(prob8)
sol9 = solve(prob9,trajectories=100);
summ9 = MonteCarloSummary(sol9,0:1:50)
plot(summ9,labels="Middle 95%")
summ10 = EnsembleSummary(sol9,0:1:50;quantiles=[0.35,0.65])
plot!(summ10,labels="Middle 50%",legend=true)
title!("Response to variability of linear pathway")
xlabel!("Time [s]")
ylabel!("Concentration[M]")

# %% [markdown]
# ## Steady state analysis of a positive feedback Loop
#
# One of the most important features of a positive feedback is the ability to add a bistable response. In other words, a positive feedback can provide the ingredients to generate two stable stady states. This bistable regime presents some relevant characteristics, such as dependence on the initial conditions.  The final steady state of teh system not only depends on the kinetic parameters of the interactions, but also on the initial conditions. This can be seen as a sort of memory or hysteresis: the system remembers its initial state and behaves transitioning to a final steady state that depends on its initial value.
#
# To visualize the number of steady states in a positive feedback without using a numerical solution of the sistem, we can find teh stady state of the system. To do that, we solve the following equations:
#
# $$
# \begin{align*}
# \frac{\mathrm{d} [M]}{\mathrm{d} t} &= 0 \tag{6}\\
# \frac{\mathrm{d} [P]}{\mathrm{d} t} &= 0
# \end{align*}
# $$
#
# which results in
#
# $$
# \begin{align*}
#  \alpha_m \frac{[P]^n}{K^n+[P]^n}-\gamma_M[M] &= 0 \tag{6}\\
#  \alpha_P [M]-\gamma_P [P] &=0
# \end{align*}
# $$
#
# From the second equation we obtain $[M] =\frac{\gamma_P}{\alpha_P}[P]$
# This substituted into the first equations leads us to the following:
#
# $$
# \begin{align*}
# [P] &=  \frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} \frac{[P]^n}{K^n+[P]^n} \tag{6}\\
# [P] \cdot (K^n+[P]^{n}) &=  \frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} [P]^n\\
# K^n+[P]^{n} &=  \frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} [P]^{n-1}
# \end{align*}
# $$
#
# for the case `n=2` we have:
#
# $$
# \begin{align*}
# [P]^{2} -  \frac{\alpha_m \alpha_P}{\gamma_M \gamma_P}   [P] + K^2 =0 \tag{6}
# \end{align*}
# $$
#
# which has as solution
# $$
# [P]=\frac{\frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} \pm\sqrt{(\frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} )^2-4  K^2}}{2}
# $$
#
# which are both positive if
#
# $$
# (\frac{\alpha_m \alpha_P}{\gamma_M \gamma_P})^2 > (\frac{\alpha_m \alpha_P}{\gamma_M \gamma_P} )^2-4  K^2
# $$
# which is allways true.
#
# We can calculate the numerical value for this set of parameters:

# %%
P_ = LinRange(0,15,100)
n=2
K=1
k_m=5
D=1
α_M=k_m*D
γ_M=0.3
α_P=0.2
γ_P=0.3

B=(α_M*α_P/(γ_M*γ_P))
P1_0=(B+sqrt(B^2-4*K^2))/2
M1_0=(P1_0)*γ_P/α_P
println("solution 1 is [P] = $P1_0, [M] = 4$M1_0")
P2_0=(B-sqrt(B^2-4*K^2))/2
M2_0=(P2_0)*γ_P/α_P
println("solution 2 is [P] = $P2_0, [M] = 4$M2_0")
# Out:
# solution 1 is [P] = 11.020370056603529, [M] = 416.53055508490529
# solution 2 is [P] = 0.09074105450758285, [M] = 40.13611158176137428

# %% [markdown]
# In addition, we can calculate and plot the Nullclines, which plot the values for which function is zero. Each intersection of the nulclines corresponds with a steady state of the system. Therefore:
#
# $$
# \begin{align*}
# f(M,P) &=  \alpha_m \frac{[P]^n}{K^n+[P]^n}-\gamma_M[M] \tag{6}\\
# g(M,P) &=  \alpha_P [M]-\gamma_P[P]
# \end{align*}
# $$
#
#
# $$
# \begin{align*}
# [M] &=  \frac{\alpha_m}{\gamma_M} \frac{[P]^n}{K^n+[P]^n} \tag{6}\\
# [M] &=\frac{\gamma_P}{\alpha_P}[P]
# \end{align*}
# $$

# %%
M1 = α_M./γ_M.*P_.^n./(K.^n .+P_.^n)
M2 = γ_P./α_P.*P_;

# %%
plot(P_,M1,label="Nullcline f")
plot!(P_,M2,label="Nullcline g")
title!("Null clines")
xlabel!(" Concentration of P [M]")
ylabel!("Concentration of M [M]")
plot!([P1_0],[M1_0],marker = :hexagon,label="steady state 1")
plot!([P2_0],[M2_0],marker = :hexagon,label="steady state 2",legend=:bottomright)

# %% [markdown]
# We see that, for these parameter values, the system of equations has two solutions that show the possible steady states of the system. One solution is the point [0,0], that corresponds to no activation of the promoter (we can call it the "__off__" solution). The other solution corresponds to a state where the gene is being actively trassncribed and promoted by teh presence of the protein $P$ that acts as transcription factor of itself. This solution can be calle the "__on__" steady state.  It is impotjnat here to remember that the two solutions are possible for the same set of parameters, and wheter the system ends up in one or another depends only on the initial conditions. To show these, we define two functions and solve the system numerically for diffenret values of the initial concentration of $M$

# %%
function PlotPositiveFeedback1(a)
     u₀ = [a,0.0]
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     x=(" u0 = $u₀")
     sol1 = solve(prob1)
     plot!(sol1,vars=(1),label=x,ylims = (0,20))
end

function PlotPositiveFeedback2(a)
     u₀ = [a,0.0]
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     x=(" u0 = $u₀")
     sol1 = solve(prob1)
     plot!(sol1,vars=(2),label=x,ylims = (0,15))
end
# Out:
# PlotPositiveFeedback2 (generic function with 1 method)

# %%
tspan = (0.0,40.0)
plot()
for i in [0.02,0.03,0.05,0.55,1,2]
    PlotPositiveFeedback1(i)
end
     xlabel!("Time [s]")
     ylabel!("Concentration [M]")
     title!("Dynamics of M in a positive feedback loop")

# %%
tspan = (0.0,40.0)
plot()
for i in [0.02,0.03,0.05,0.55,1,2]
    PlotPositiveFeedback2(i)
end
     xlabel!("Time [s]")
     ylabel!("Concentration [M]")
     title!("Dynamics of P in a positive feedback loop")

# %%
tspan = (0.0,20.0)
n=3
K=1
k_m=5
D=1
T=3
α_M=k_m*D
γ_M=0.3
α_P=1
γ_P=0.3
p=[α_M,γ_M,T,n,α_P,γ_P,K];



function PlotPositiveFeedback(a)
     u₀ = [a,0.0]
     p=[α_M,γ_M,T,n,α_P,γ_P,K];
     prob1 = ODEProblem(PositiveFeedback!,u₀,tspan,p)
     x=(" u0 = $u₀")
     sol1 = solve(prob1)
     plot!(sol1,vars=(1),label=x,ylims = (0,20))
end

plot()
for i in [0.02,0.03,0.05,0.55,1,2]
    PlotPositiveFeedback(i)
end
     xlabel!("Time [s]")
     ylabel!("Concentration [M]")
     title!("Positive feedback")

# %% [markdown]
# Close to this bifurcation is where noise and stochasticity is highly amplified. This is due to the presence of the two basins of atraction for each steady state. This amplification of noise can be compared with the behavior of the linear system, under consitions of similar noise intensity.

# %%
NoiseFunction! = @ode_def negFB begin
   dM = 0.05
   dP = 0.0
    end α_M γ_M T n α_P γ_P K

u₀ = [0.52,0.01]
prob6 = SDEProblem(PositiveFeedback!,NoiseFunction!,u₀,tspan,p)
prob7 = MonteCarloProblem(prob6)
sol7 = solve(prob7,trajectories=100);
summ7 = EnsembleSummary(sol7,0:1:20)
plot(summ7,labels="Middle 95%")
summ8 = EnsembleSummary(sol7,0:1:20;quantiles=[0.35,0.65])
plot!(summ8,labels="Middle 50%",legend=true,ylims = (0,2.5))
title!("Response to variability of positive feedback GRN")
xlabel!("Time [s]")
ylabel!("Concentration[M]")

# %%
prob8 = SDEProblem(NoFeedback!,NoiseFunction!,u₀,tspan,p)
prob9 = MonteCarloProblem(prob8)
sol9 = solve(prob9,trajectories=100);
summ9 = EnsembleSummary(sol9,0:1:20)
plot(summ9,labels="Middle 95%")
summ10 = EnsembleSummary(sol9,0:1:20;quantiles=[0.35,0.65])
plot!(summ10,labels="Middle 50%",legend=true,xlims = (0,6),ylims = (0,2.5))
title!("Response to variability of linear pathway")
xlabel!("Time [s]")
ylabel!("Concentration[M]")

# %% [markdown]
# ## Conclusion
#
# We can clearly see that the variability in the output due to sctochasticity in gene expression in the output of the linear system is lower in linear networks than in networks with a positive feedback loop. In conclusion, the presence of a protein that activates directly or indirectly its own production induces the following properties and features in a gene regulatory network:
#
# - Slower dynamics
# - Delays
# - Amplification of changes in input
# - Worse reliability in conditions of high cooperativity
# - Amplification of noise
# - Bistability, histereresis, dependence on initial conditions.

# %% [markdown]
# ### <font color=red>Computer Task:</font>
#
# Choose one of the six features listed above and one parameter of the model. Study how changes in this parameter affect the feature that you have chosen (you need to compare the output of the positive feedback and the linear system).
